# %% [markdown]
# <h1>Primer Examen parcial</h1>

# %% [markdown]
# <h4>INTRODUCCIÓN</h4>

# %% [markdown]
# <h4>MODELADO CINEMÁTICO DE LA POSTURA</h4>

# %% [markdown]
# <h4>MODELADO CINEMÁTICO DE LAS VELOCIDADES</h4>

# %% [markdown]
# <h4>MODELADO CINEMÁTICO DE LAS ACELERACIONES</h4>

# %% [markdown]
# <h4>MODELADO DINÁMICO</h4>
